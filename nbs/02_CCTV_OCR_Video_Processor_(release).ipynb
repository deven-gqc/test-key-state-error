# %% [markdown]
# # CCTV OCR
# > This notebook is the CCTV OCR video processor
# - skip_exec: true
# - skip_showdoc: true

# %% [markdown]
# ## Mount GDrive and Setup the modules
#
# Run this section once.
# Restart the kernel and run once again.
